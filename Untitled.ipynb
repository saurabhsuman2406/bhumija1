# %%
import numpy as np
import pandas as pd
df=pd.read_csv('Diagnostic_Laboratory.csv')
df
# Out:
#     SNo      State Name  District Name  \
# 0     1      CHANDIGARH            NaN
# 1     2             GOA            NaN
# 2     3         GUJARAT            NaN
# 3     4         HARYANA            NaN
# 4     5         HARYANA            NaN
# ..  ...             ...            ...
# 95   96  ANDHRA PRADESH  Visakhapatnam
# 96   97  ANDHRA PRADESH   Vizianagaram
# 97   98  ANDHRA PRADESH       Warangal
# 98   99  ANDHRA PRADESH  West Godavari
# 99  100  ANDHRA PRADESH         Y.S.R.
#
#                                                 ADDL  \
# 0                                         CHANDIGARH
# 1                         DISEASE INVESTIGATION UNIT
# 2                  Poultry Disease Investigation Lab
# 3   District Disease Diagnostic Lab. Deptt of Animal
# 4                                            HARYANA
# ..                                               ...
# 95                                ADDL,Visakhapatnam
# 96                                 ADDL,Vizianagaram
# ...

# %%
df.dropna()
# Out:
#     SNo      State Name                District Name                ADDL  \
# 35   36  ANDHRA PRADESH                     Adilabad      ADDL, Adilabad
# 37   38  ANDHRA PRADESH                    Anantapur      ADDL,Anantapur
# 44   45  ANDHRA PRADESH                     Chittoor       ADDL,Chittoor
# 50   51  ANDHRA PRADESH                East Godavari       ADDL,Kakinada
# 53   54  ANDHRA PRADESH                       Guntur         ADDL,Guntur
# 62   63  ANDHRA PRADESH                      Krishna     ADDL,Vijayawada
# 78   79  ANDHRA PRADESH                     Prakasam         ADDL,Ongole
# 89   90  ANDHRA PRADESH  Sri Potti Sriramulu Nellore        ADDL,Nellore
# 95   96  ANDHRA PRADESH                Visakhapatnam  ADDL,Visakhapatnam
# 96   97  ANDHRA PRADESH                 Vizianagaram   ADDL,Vizianagaram
# 98   99  ANDHRA PRADESH                West Godavari          ADDL,Eluru
# 99  100  ANDHRA PRADESH                       Y.S.R.         ADDL,Kadapa
#
# ...

# %%
df
# Out:
#     SNo      State Name  District Name  \
# 0     1      CHANDIGARH            NaN
# 1     2             GOA            NaN
# 2     3         GUJARAT            NaN
# 3     4         HARYANA            NaN
# 4     5         HARYANA            NaN
# ..  ...             ...            ...
# 95   96  ANDHRA PRADESH  Visakhapatnam
# 96   97  ANDHRA PRADESH   Vizianagaram
# 97   98  ANDHRA PRADESH       Warangal
# 98   99  ANDHRA PRADESH  West Godavari
# 99  100  ANDHRA PRADESH         Y.S.R.
#
#                                                 ADDL  \
# 0                                         CHANDIGARH
# 1                         DISEASE INVESTIGATION UNIT
# 2                  Poultry Disease Investigation Lab
# 3   District Disease Diagnostic Lab. Deptt of Animal
# 4                                            HARYANA
# ..                                               ...
# 95                                ADDL,Visakhapatnam
# 96                                 ADDL,Vizianagaram
# ...

# %%
df.to_csv('Diagnostic_Laboratoryfinal.csv',index=False)

# %%
df.head(100)
# Out:
#     SNo      State Name  District Name  \
# 0     1      CHANDIGARH            NaN
# 1     2             GOA            NaN
# 2     3         GUJARAT            NaN
# 3     4         HARYANA            NaN
# 4     5         HARYANA            NaN
# ..  ...             ...            ...
# 95   96  ANDHRA PRADESH  Visakhapatnam
# 96   97  ANDHRA PRADESH   Vizianagaram
# 97   98  ANDHRA PRADESH       Warangal
# 98   99  ANDHRA PRADESH  West Godavari
# 99  100  ANDHRA PRADESH         Y.S.R.
#
#                                                 ADDL  \
# 0                                         CHANDIGARH
# 1                         DISEASE INVESTIGATION UNIT
# 2                  Poultry Disease Investigation Lab
# 3   District Disease Diagnostic Lab. Deptt of Animal
# 4                                            HARYANA
# ..                                               ...
# 95                                ADDL,Visakhapatnam
# 96                                 ADDL,Vizianagaram
# ...

# %%
import pandas as pd
import sqlite3
conn = sqlite3.connect(r"D:\saurabh\code\bhoomija\bhoomi\rekha.db")
#conn.text_factory = bytes
conn.text_factory = lambda b: b.decode(errors = 'ignore')
State_Name="Karnataka"
q="select * from Diagnostic_Laboratory;"
df = pd.read_sql_query(q, conn)
df.fillna('')
print(q)
df
# Out:
# select * from Diagnostic_Laboratory;
#     SNo      State Name  District Name  \
# 0     1      CHANDIGARH
# 1     2             GOA
# 2     3         GUJARAT
# 3     4         HARYANA
# 4     5         HARYANA
# ..  ...             ...            ...
# 95   96  ANDHRA PRADESH  Visakhapatnam
# 96   97  ANDHRA PRADESH   Vizianagaram
# 97   98  ANDHRA PRADESH       Warangal
# 98   99  ANDHRA PRADESH  West Godavari
# 99  100  ANDHRA PRADESH         Y.S.R.
#
#                                                 ADDL  \
# 0                                         CHANDIGARH
# 1                         DISEASE INVESTIGATION UNIT
# 2                  Poultry Disease Investigation Lab
# 3   District Disease Diagnostic Lab. Deptt of Animal
# 4                                            HARYANA
# ..                                               ...
# 95                                ADDL,Visakhapatnam
# 96                                 ADDL,Vizianagaram
# ...

# %%
conn.close()

# %%
import numpy as np
import pandas as pd
df=pd.read_csv('msp.csv')
df
# Out:
#              Commodity        Variety  2010-11  2011-12  2012-13  2013-14  \
# 0                PADDY         Common     1000     1080     1250     1310
# 1                PADDY      Grade 'A'     1030     1110     1280     1345
# 2                JOWAR         Hybrid      880      980     1500     1500
# 3                JOWAR       Maldandi      900     1000     1520     1520
# 4                BAJRA            NaN      880      980     1175     1250
# 5                MAIZE            NaN      880      980     1175     1310
# 6                 RAGI            NaN      965     1050     1500     1500
# 7          Tur (Arhar)            NaN     3000     3200     3850     4300
# 8                MOONG            NaN     3170     3500     4400     4500
# 9                 URAD            NaN     2900     3300     4300     4300
# 10              COTTON  Medium Staple     2500     2800     3600     3700
# 11              COTTON    Long Staple     3000     3300     3900     4000
# ...

# %%
import pandas as pd
import sqlite3
conn = sqlite3.connect(r"D:\saurabh\code\bhoomija\bhoomi\rekha.db")
#conn.text_factory = bytes
conn.text_factory = lambda b: b.decode(errors = 'ignore')
#State_Name="Karnataka"
q="select * from msp;"
df = pd.read_sql_query(q, conn)
df.fillna('')
print(q)
df
# Out:
# select * from msp;
#              Commodity        Variety 2010-11 2011-12 2012-13 2013-14 2014-15  \
# 0                PADDY         Common    1000    1080    1250    1310    1360
# 1                PADDY      Grade 'A'    1030    1110    1280    1345    1400
# 2                JOWAR         Hybrid     880     980    1500    1500    1530
# 3                JOWAR       Maldandi     900    1000    1520    1520    1550
# 4                BAJRA                    880     980    1175    1250    1250
# 5                MAIZE                    880     980    1175    1310    1310
# 6                 RAGI                    965    1050    1500    1500    1550
# 7          Tur (Arhar)                   3000    3200    3850    4300    4350
# 8                MOONG                   3170    3500    4400    4500    4600
# 9                 URAD                   2900    3300    4300    4300    4350
# 10              COTTON  Medium Staple    2500    2800    3600    3700    3750
# ...

# %%
df['Final']="MSP for "+df['Commodity']+" "+df['Variety']+" is Rs. "+df['2020-21']+" in 2020-21"
df.dropna(inplace=True)
for i in df["Final"]:
    print(i)
# Out:
# MSP for PADDY Common is Rs. 1868 in 2020-21
# MSP for PADDY Grade 'A' is Rs. 1888 in 2020-21
# MSP for JOWAR Hybrid is Rs. 2620 in 2020-21
# MSP for JOWAR Maldandi is Rs. 2640 in 2020-21
# MSP for BAJRA  is Rs. 2150 in 2020-21
# MSP for MAIZE  is Rs. 1850 in 2020-21
# MSP for RAGI  is Rs. 3295 in 2020-21
# MSP for Tur (Arhar)  is Rs. 6000 in 2020-21
# MSP for MOONG  is Rs. 7196 in 2020-21
# MSP for URAD  is Rs. 6000 in 2020-21
# MSP for COTTON Medium Staple is Rs. 5515 in 2020-21
# MSP for COTTON Long Staple is Rs. 5825 in 2020-21
# MSP for Groundnut  is Rs. 5275 in 2020-21
# MSP for SUNFLOWER SEED  is Rs. 5885 in 2020-21
# MSP for SOYABEAN Black is Rs.  in 2020-21
# MSP for SOYABEAN Yellow is Rs. 3880 in 2020-21
# MSP for SESAMUM  is Rs. 6855 in 2020-21
# MSP for NIGERSEED  is Rs. 6695 in 2020-21
# MSP for WHEAT  is Rs. 1975 in 2020-21
# MSP for BARLEY  is Rs. 1600 in 2020-21
# MSP for GRAM  is Rs. 5100 in 2020-21
# MSP for MASUR (LENTIL)  is Rs. 5100 in 2020-21
# ...
